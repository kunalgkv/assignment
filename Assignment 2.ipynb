# %%
#Assignment 2

# %%
Q1. How do you comment code in Python? What are the different types of comments?

In Python, we can comment code using the `#` symbol for single-line comments and using triple quotes `""" """` or `''' '''` for multi-line comments.

Example:


# This is a single-line comment

"""
This is a
multi-line
comment
"""

# or

'''
This is also a
multi-line
comment
'''


Q2. What are variables in Python? How do you declare and assign values to variables?

Variables in Python are used to store and manipulate data. They act as placeholders for values that can be accessed and modified throughout the program. To declare and assign values to variables, we uses the following syntax:


variable_name = value


Example:

x = 5
name = "Kunal"


Q3. How do you convert one data type to another in Python?

In Python, we can convert one data type to another using type conversion functions or constructors. Here are some examples:


# Converting a string to an integer
num_str = "10"
num_int = int(num_str)

# Converting an integer to a string
num_int = 10
num_str = str(num_int)

# Converting a string to a float
float_str = "3.14"
num_float = float(float_str)

# Converting a float to an integer
num_float = 3.14
num_int = int(num_float)


Q4. How do you write and execute a Python script from the command line?

To write and execute a Python script from the command line, we can follow these steps:

1. Open a text editor and write your Python code.
2. Save the file with a `.py` extension, such as `script.py`.
3. Open a command prompt or terminal.
4. Navigate to the directory where the Python script is saved using the `cd` command.
5. Execute the script using the command `python script.py`, replacing `script.py` with the actual name of your script file.

Q5. Given a list `my_list = [1, 2, 3, 4, 5]`, write the code to slice the list and obtain the sub-list `[2, 3]`.

We can use list slicing in Python to obtain a sub-list. In this case, to get the sub-list `[2, 3]` from `my_list`, we can use the following code:


my_list = [1, 2, 3, 4, 5]
sub_list = my_list[1:3]
print(sub_list)


Output:

[2, 3]


Q6. What is a complex number in mathematics, and how is it represented in Python?

In mathematics, a complex number is a number of the form `a + bj`, where `a` and `b` are real numbers, and `j` is the imaginary unit equal to the square root of -1.

In Python, complex numbers are represented using the `complex` data type. The imaginary part is denoted using the `j` or `J` suffix.

Example:


z = 3 + 2j
print(z)  # Output: (3+2j)


Q7. What is the correct way to declare a variable named `age` and assign the value `25` to it?

The correct way to declare a variable named `age` and assign the value `25` to it is as follows:


age = 25


Q8. Declare a variable named `price` and assign the value `9.99` to it. What data type does this variable belong to?

To declare a variable named `price` and assign the value `9.99` to it, we can use the following code:


price = 9.99


The variable `price` belongs to the data type `float`, which represents decimal numbers in Python.

Q9. Create a variable named `name` and assign your full name to it as a string. How would you print the value of this variable?

To create a variable named `name` and assign your full name to it as a string, we can use the following code:

//replaced your full name to kunal
name = "kunal"


To print the value of the `name` variable, we can use the `print()` function:


print(name)


This will output kunal.

Q10. Given the string `"Hello, World!"`, extract the substring `"World"`.

To extract the substring `"World"` from the string `"Hello, World!"`, we can use string slicing. Here's an example:


s = "Hello, Love!"
substring = s[7:]
print(substring)

Output:
World!


Q11. Create a variable named `is_student` and assign it a boolean value indicating whether you are currently a student or not.

To create a variable named `is_student` and assign it a boolean value indicating whether you are currently a student or not, we can use the following code:


is_student = True  # Assign True or False based on your current status as a student
